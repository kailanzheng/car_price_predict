# %%
#coding:utf-8
#导入warnings包，利用过滤器来实现忽略警告语句。
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
Train_data = pd.read_csv('used_car_train_20200313.csv', sep=' ')
Test_data = pd.read_csv('used_car_testB_20200421.csv', sep=' ')

# %% [markdown]
# ### 以下为数据集的特征
# ![image.png](attachment:image.png)

# %%
# 1.数据探索性分析
## 1.1 简单看下数据
Train_data.head().append(Train_data.tail())
# Out:
#         SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  \
# 0            0     736  20040402   30.0      6       1.0       0.0      0.0
# 1            1    2262  20030301   40.0      1       2.0       0.0      0.0
# 2            2   14874  20040403  115.0     15       1.0       0.0      0.0
# 3            3   71865  19960908  109.0     10       0.0       0.0      1.0
# 4            4  111080  20120103  110.0      5       1.0       0.0      0.0
# 149995  149995  163978  20000607  121.0     10       4.0       0.0      1.0
# 149996  149996  184535  20091102  116.0     11       0.0       0.0      0.0
# 149997  149997  147587  20101003   60.0     11       1.0       1.0      0.0
# 149998  149998   45907  20060312   34.0     10       3.0       1.0      0.0
# 149999  149999  177672  19990204   19.0     28       6.0       0.0      1.0
#
#         power  kilometer  ...       v_5       v_6       v_7       v_8  \
# ...

# %%
Test_data.head().append(Test_data.tail())
# Out:
#        SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  \
# 0      200000  133777  20000501   67.0      0       1.0       0.0      0.0
# 1      200001   61206  19950211   19.0      6       2.0       0.0      0.0
# 2      200002   67829  20090606    5.0      5       4.0       0.0      0.0
# 3      200003    8892  20020601   22.0      9       1.0       0.0      0.0
# 4      200004   76998  20030301   46.0      6       0.0       NaN      0.0
# 49995  249995  111443  20041005    4.0      4       0.0       NaN      1.0
# 49996  249996  152834  20130409   65.0      1       0.0       0.0      0.0
# 49997  249997  132531  20041211    4.0      4       0.0       0.0      1.0
# 49998  249998  143405  20020702   40.0      1       4.0       0.0      1.0
# 49999  249999   78202  20090708   32.0      8       1.0       0.0      0.0
#
#        power  kilometer  ...       v_5       v_6       v_7       v_8  \
# 0        101       15.0  ...  0.236520  0.000241  0.105319  0.046233
# ...

# %%
## 1.2 查看数据的相关统计量以及缺失值情况
Train_data.describe()
Test_data.describe()
# Out:
#               SaleID           name       regDate        model         brand  \
# count   50000.000000   50000.000000  5.000000e+04  50000.00000  50000.000000
# mean   224999.500000   68505.606100  2.003401e+07     47.64948      8.087140
# std     14433.901067   61032.124271  5.351615e+04     49.90741      7.899648
# min    200000.000000       1.000000  1.991000e+07      0.00000      0.000000
# 25%    212499.750000   11315.000000  1.999100e+07     11.00000      1.000000
# 50%    224999.500000   52215.000000  2.003091e+07     30.00000      6.000000
# 75%    237499.250000  118710.750000  2.007110e+07     66.00000     13.000000
# max    249999.000000  196808.000000  2.015121e+07    246.00000     39.000000
#
#            bodyType      fuelType       gearbox         power     kilometer  \
# count  48496.000000  47076.000000  48032.000000  50000.000000  50000.000000
# mean       1.793736      0.376498      0.226953    119.766960     12.598260
# ...

# %%
# bodyType，fuelType，gearbox存在缺失值，缺失值最多的占总样本的5.79%，没有超过三成
# 如果缺失值个数很少可以选择填充的方式，lgb等树模型也可以处理缺失值，但如果缺失值过多可以考虑删掉该特征
Train_data.isnull().sum()
# Out:
# SaleID                  0
# name                    0
# regDate                 0
# model                   1
# brand                   0
# bodyType             4506
# fuelType             8680
# gearbox              5981
# power                   0
# kilometer               0
# notRepairedDamage       0
# regionCode              0
# seller                  0
# offerType               0
# creatDate               0
# price                   0
# v_0                     0
# v_1                     0
# v_2                     0
# v_3                     0
# v_4                     0
# v_5                     0
# v_6                     0
# v_7                     0
# v_8                     0
# v_9                     0
# v_10                    0
# v_11                    0
# v_12                    0
# v_13                    0
# v_14                    0
# dtype: int64

# %%
Test_data.isnull().sum()
# Out:
# SaleID                  0
# name                    0
# regDate                 0
# model                   0
# brand                   0
# bodyType             1504
# fuelType             2924
# gearbox              1968
# power                   0
# kilometer               0
# notRepairedDamage       0
# regionCode              0
# seller                  0
# offerType               0
# creatDate               0
# v_0                     0
# v_1                     0
# v_2                     0
# v_3                     0
# v_4                     0
# v_5                     0
# v_6                     0
# v_7                     0
# v_8                     0
# v_9                     0
# v_10                    0
# v_11                    0
# v_12                    0
# v_13                    0
# v_14                    0
# dtype: int64

# %%
# 我们看看每一个特征都是些什么值，有没有存在异常的值
for feature in Train_data.columns:
    print(Train_data[feature].value_counts(), '\n')
# 由结果可以看到notRepairedDamage存在-，这也是一种缺失值，可以替换成np.nan再处理
# 并且seller跟offerType类别严重倾斜，可以删掉
# Out:
# 2047      1
# 113949    1
# 15661     1
# 13612     1
# 3371      1
#          ..
# 8913      1
# 10960     1
# 53967     1
# 56014     1
# 0         1
# Name: SaleID, Length: 150000, dtype: int64
#
# 708       282
# 387       282
# 55        280
# 1541      263
# 203       233
#          ...
# 5074        1
# 7123        1
# 11221       1
# 13270       1
# 174485      1
# Name: name, Length: 99662, dtype: int64
#
# 20000008    180
# 20000011    158
# 20000004    157
# 20000010    157
# 20000002    155
#            ...
# 19910807      1
# 19910902      1
# 20151209      1
# 19911011      1
# 20151201      1
# Name: regDate, Length: 3894, dtype: int64
#
# 0.0      11762
# 19.0      9573
# 4.0       8445
# 1.0       6038
# 29.0      5186
#          ...
# 245.0        2
# 209.0        2
# 240.0        2
# 242.0        2
# 247.0        1
# Name: model, Length: 248, dtype: int64
#
# 0     31480
# 4     16737
# 14    16089
# 10    14249
# 1     13794
# 6     10217
# 9      7306
# ...

# %%
# 测试集也存在同样的情况
for feature in Test_data.columns:
    print(Test_data[feature].value_counts(), '\n')
# Out:
# 200702    1
# 234840    1
# 208239    1
# 206190    1
# 212333    1
#          ..
# 201399    1
# 203446    1
# 209587    1
# 211634    1
# 200706    1
# Name: SaleID, Length: 50000, dtype: int64
#
# 387       94
# 55        93
# 1541      86
# 708       85
# 203       78
#           ..
# 97691      1
# 155039     1
# 44449      1
# 112034     1
# 105129     1
# Name: name, Length: 37536, dtype: int64
#
# 20000012    61
# 20000002    56
# 20000001    56
# 20000006    56
# 20000008    55
#             ..
# 19920901     1
# 19920911     1
# 19920212     1
# 19930209     1
# 20130010     1
# Name: regDate, Length: 3819, dtype: int64
#
# 0.0      3772
# 19.0     3226
# 4.0      2790
# 1.0      1981
# 29.0     1778
#          ...
# 229.0       2
# 209.0       2
# 242.0       1
# 241.0       1
# 244.0       1
# Name: model, Length: 245, dtype: int64
#
# 0     10473
# 4      5532
# 14     5345
# 10     4713
# 1      4627
# 6      3500
# 9      2360
# 5      1485
# 13     1386
# 11      942
# ...

# %%
Train_data['notRepairedDamage'].replace('-', np.nan, inplace = True)
Test_data['notRepairedDamage'].replace('-', np.nan, inplace = True)
del Train_data["seller"]
del Train_data["offerType"]
del Test_data["seller"]
del Test_data["offerType"]
Train_data.isnull().sum()
# Out:
# SaleID                   0
# name                     0
# regDate                  0
# model                    1
# brand                    0
# bodyType              4506
# fuelType              8680
# gearbox               5981
# power                    0
# kilometer                0
# notRepairedDamage    24324
# regionCode               0
# creatDate                0
# price                    0
# v_0                      0
# v_1                      0
# v_2                      0
# v_3                      0
# v_4                      0
# v_5                      0
# v_6                      0
# v_7                      0
# v_8                      0
# v_9                      0
# v_10                     0
# v_11                     0
# v_12                     0
# v_13                     0
# v_14                     0
# dtype: int64

# %%
# 1.3了解数据的分布
# 数字特征和类型特征
# numeric_features = Train_data.select_dtypes(include=[np.number])
# categorical_features = Train_data.select_dtypes(include=[np.object])
numeric_features = ['power', 'kilometer', 'v_0', 'v_1', 'v_2', 'v_3', 'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12', 'v_13','v_14' ]
categorical_features = ['name', 'model', 'brand', 'bodyType', 'fuelType', 'gearbox', 'notRepairedDamage', 'regionCode',]

# %%
# 1.3.1数字特征的分布
plot_kind = ['line','bar','barh','hist','box','kde','density','area','pie','scatter','hexbin']

numeric_features.append('price')
f = pd.melt(Train_data, value_vars = numeric_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")
'''查看特征的偏度和峰值
for col in numeric_features:
    print('{:15}'.format(col), 
          'Skewness: {:05.2f}'.format(Train_data[col].skew()) , 
          '   ' ,
          'Kurtosis: {:06.2f}'.format(Train_data[col].kurt())  
         )'''
# 从分布可视化来看，power，kilometer，v2，v5，v6，v7，price均存在长尾分布的情况

# %%
# 1.3.2类型特征的分布，类别特征的柱形图可视化
# 类型特征中的name跟regionCode的类别太稀疏了
categorical_features = ['model','brand','bodyType','fuelType', 'gearbox','notRepairedDamage']

def bar_plot(x, y, **kwargs):
    sns.barplot(x=x, y=y)
    x=plt.xticks(rotation=90)

f = pd.melt(Train_data, id_vars=['price'], value_vars=categorical_features)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(bar_plot, "value", "price")
# g = g.map(count_plot, "value")

# %%
# 1.4重点了解一些特征
# 1.4.1 regDate：注册日期
# 20000008这类数据不知道是指八月还是一月八号
regDate = Train_data['regDate']
for i in range (len(regDate)):
    item = str(regDate.loc[i])
    if item[4:6] == '00':
        item = item[:4] + item[-2:] + '01'
        regDate.loc[i] = item
regDate = pd.to_datetime(regDate, format='%Y%m%d')
regDate = pd.DataFrame(regDate.value_counts())
regDate.sort_values(by='regDate',ascending=False,inplace=True)
regDate.head(30).plot.bar()

# %%
# 1.4.2 creatDate：汽车上线时间
# 20000008这类数据不知道是指八月还是一月八号
# createDate - rDate 就是这辆车的已使用时间，这个可以构建一个特征
creatDate = Train_data['creatDate']
for i in range (len(creatDate)):
    item = str(creatDate.loc[i])
    if item[4:6] == '00':
        item = item[:4] + item[-2:] + '01'
        creatDate.loc[i] = item
creatDate = pd.to_datetime(creatDate, format='%Y%m%d')
creatDate = pd.DataFrame(creatDate.value_counts())
creatDate.sort_values(by='creatDate',ascending=False,inplace=True)
creatDate.head(30).plot.bar()

# %%
# 1.4.3针对各个数字特征做相关性分析，了解他们的相关性
# 减小特征之间的冗余，模型的参数的更新可能是去处理冗余特征之间的权重去了，没有实质上的进步。
# 分析完，在相互相关的特征中选取一个或者多个，从而降维、处理冗余特征
price_numeric = Train_data[numeric_features]
correlation = price_numeric.corr()
# 查看各特征与price间的相关性
print(correlation['price'].sort_values(ascending = False),'\n')
# Out:
# price        1.000000
# v_12         0.692823
# v_8          0.685798
# v_0          0.628397
# power        0.219834
# v_5          0.164317
# v_2          0.085322
# v_6          0.068970
# v_1          0.060914
# v_14         0.035911
# v_13        -0.013993
# v_7         -0.053024
# v_4         -0.147085
# v_9         -0.206205
# v_10        -0.246175
# v_11        -0.275320
# kilometer   -0.440519
# v_3         -0.730946
# Name: price, dtype: float64

# %%
f , ax = plt.subplots(figsize = (7, 7))
plt.title('Correlation of Numeric Features with Price',y=1,size=16)
sns.heatmap(correlation,square = True,  vmax=0.8)
# 可以看到有很几个匿名特征间相关性很高，后续可以考虑做进一步处理

# %%
sns.set()
columns = ['price', 'v_12', 'v_8' , 'v_0', 'power', 'v_5',  'v_2', 'v_6', 'v_1', 'v_14']
sns.pairplot(Train_data[columns],size = 2 ,kind ='scatter',diag_kind='kde')
plt.show()

# %%
# 1.5用箱型图观察异常值,后续用3σ准则处理异常值
for col in numeric_features:
    Train_data[col].plot(kind='box')
    plt.show()

# %% [markdown]
# ### 总结：EDA是为了后续的特征工程做准备，要做特征工程首先要了解数据的一些情况，后续在特征工程时，还要回过来继续EDA
